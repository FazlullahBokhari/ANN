# %%
import os

root = '/content/drive/MyDrive/Deep Learning'
os.chdir(root)

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import os
plt.style.use('fivethirtyeight')

# %%
x = np.linspace(-10,10,100)
x
# Out:
# array([-10.        ,  -9.7979798 ,  -9.5959596 ,  -9.39393939,
#         -9.19191919,  -8.98989899,  -8.78787879,  -8.58585859,
#         -8.38383838,  -8.18181818,  -7.97979798,  -7.77777778,
#         -7.57575758,  -7.37373737,  -7.17171717,  -6.96969697,
#         -6.76767677,  -6.56565657,  -6.36363636,  -6.16161616,
#         -5.95959596,  -5.75757576,  -5.55555556,  -5.35353535,
#         -5.15151515,  -4.94949495,  -4.74747475,  -4.54545455,
#         -4.34343434,  -4.14141414,  -3.93939394,  -3.73737374,
#         -3.53535354,  -3.33333333,  -3.13131313,  -2.92929293,
#         -2.72727273,  -2.52525253,  -2.32323232,  -2.12121212,
#         -1.91919192,  -1.71717172,  -1.51515152,  -1.31313131,
#         -1.11111111,  -0.90909091,  -0.70707071,  -0.50505051,
#         -0.3030303 ,  -0.1010101 ,   0.1010101 ,   0.3030303 ,
#          0.50505051,   0.70707071,   0.90909091,   1.11111111,
#          1.31313131,   1.51515152,   1.71717172,   1.91919192,
#          2.12121212,   2.32323232,   2.52525253,   2.72727273,
#          2.92929293,   3.13131313,   3.33333333,   3.53535354,
#          3.73737374,   3.93939394,   4.14141414,   4.34343434,
#          4.54545455,   4.74747475,   4.94949495,   5.15151515,
#          5.35353535,   5.55555556,   5.75757576,   5.95959596,
#          6.16161616,   6.36363636,   6.56565657,   6.76767677,
#          6.96969697,   7.17171717,   7.37373737,   7.57575758,
#          7.77777778,   7.97979798,   8.18181818,   8.38383838,
#          8.58585859,   8.78787879,   8.98989899,   9.19191919,
#          9.39393939,   9.5959596 ,   9.7979798 ,  10.        ])

# %%
len(x)
# Out:
# 100

# %%
def derivative(f, x, delta_x=1e-6):
  return (f(x + delta_x)-f(x))/(delta_x)

# %%
f=sine
derivative(f,x)
# Out:
# array([-0.8390718 , -0.93116492, -0.98538425, -0.99952451, -0.97301057,
#        -0.90692083, -0.8039434 , -0.66826674, -0.50540931, -0.32199508,
#        -0.12548417,  0.07613062,  0.27464892,  0.46199626,  0.63055258,
#         0.77346209,  0.88491215,  0.9603697 ,  0.9967656 ,  0.99261951,
#         0.94810006,  0.86501802,  0.74675262,  0.59811415,  0.42514825,
#         0.23489007,  0.03507807, -0.16616068, -0.36064108, -0.54045293,
#        -0.69828264, -0.82771072, -0.92347287, -0.9816741 , -0.99994716,
#        -0.97754882, -0.91539011, -0.81599923, -0.68341876, -0.52304123,
#        -0.34138976, -0.14585275,  0.0556166 ,  0.25482383,  0.44366647,
#         0.61446362,  0.76026836,  0.87515028,  0.95443674,  0.99490287,
#         0.99490277,  0.95443644,  0.8751498 ,  0.76026771,  0.61446283,
#         0.44366557,  0.25482286,  0.0556156 , -0.14585374, -0.3413907 ,
#        -0.52304208, -0.68341949, -0.8159998 , -0.91539051, -0.97754903,
#        -0.99994717, -0.98167391, -0.92347249, -0.82771016, -0.69828193,
#        -0.54045209, -0.36064015, -0.16615969,  0.03507907,  0.23489104,
#         0.42514916,  0.59811495,  0.74675329,  0.86501852,  0.94810038,
#         0.99261963,  0.99676552,  0.96036942,  0.88491169,  0.77346146,
#         0.63055181,  0.46199538,  0.27464795,  0.07612963, -0.12548516,
#        -0.32199603, -0.50541017, -0.66826749, -0.803944  , -0.90692125,
#        -0.9730108 , -0.99952454, -0.98538408, -0.93116455, -0.83907126])

# %%
def plot_graph(x,f, ALPHA=0.6, label_x=r"$x \rightarrow$", label_y=r"$act(x), act'(x)$",
               title=None, LABEL_Y=None, LABEL_Y_DASH=None, filepath_to_plot="plot.png"):
  
  y = f(x)
  y_dash = derivative(f,x)
  plt.figure(figsize=(10,8))
  plt.axhline(y=0, color="black", linestyle = "--", lw=2)
  plt.axvline(y=0, color="black", linestyle = "--", lw=2)
  plt.xlabel(label_x)
  plt.ylabel(label_y)

  if (LABEL_Y != None) and (LABEL_Y_DASH != None) :
    plt.plot(x,y,alpha=ALPHA, label=LABEL_Y)
    plt.plot(x,y_dash, alpha=ALPHA, label=LABEL_Y_DASH)
    plt.legend(fontsize=14)
  else:
    plt.plot(x,y,alpha=ALPHA)
    plt.plot(x,y_dash, alpha=ALPHA)
  
  plt.savefig(filepath_to_plot)

# %%
def sine(x):
  return np.sin(x) # takes radial input

# %%
root_plot_dir = "root"
os.makedirs(root_plot_dir, exist_ok=True)

# %%
def plot_sine(x,path):
  plot_graph(x,f=sine, ALPHA=0.6,
             label_x=r"$x \rightarrow$", 
             label_y=r"$act(x), act'(x)$",
             title="sine function", 
             LABEL_Y=r"$sine(x)$", 
             LABEL_Y_DASH=r"$cos(x)$", 
             filepath_to_plot="plot.png")  
  
plot_sine(x, os.path.join(root_plot_dir, "sine"))
